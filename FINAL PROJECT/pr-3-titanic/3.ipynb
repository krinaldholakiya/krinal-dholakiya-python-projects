# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("dataset.csv")
print("dataset loaded successfull!")
# Out:
# dataset loaded successfull!

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass                   Name     Sex    Age  SibSp  \
# 0            1         0       3    Thomas, Mr. Charles    male   2.40      0
# 1            2         1       2    Harris, Miss. Alice  female  43.57      0
# 2            3         0       3      White, Mrs. Ellen  female  39.19      0
# 3            4         0       3       Miller, Mr. John    male  19.31      0
# 4            5         0       1      Jackson, Mr. John    male  44.26      1
# 5            6         0       3      Jones, Mr. Edward    male  22.39      0
# 6            7         0       3      White, Miss. Mary  female  27.90      0
# 7            8         0       3    Thomas, Miss. Helen  female  11.23      2
# 8            9         1       1      Davis, Miss. Emma  female  45.47      1
# 9           10         1       2  Harris, Master. Frank    male  10.31      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      1  731858   16.17    F9        S
# 1      0  364540   20.06  E124        S
# 2      0  133235    9.60   NaN        S
# 3      0  678141    9.38   NaN        Q
# 4      0  295414     NaN   E86        Q
# 5      0  545276   10.43   NaN        S
# 6      0  787924   20.15   NaN        S
# 7      0  610493   14.59   F43        C
# 8      0  150738  124.26  A127        S
# 9      0  705179   25.16   NaN        S

# %%
df.tail(10)
# Out:
#       PassengerId  Survived  Pclass                   Name   Sex    Age  \
# 4990         4991         0       1     Jackson, Mr. Henry  male  41.54
# 4991         4992         0       3        Brown, Mr. John  male    NaN
# 4992         4993         0       3      Harris, Mr. Frank  male   7.26
# 4993         4994         0       2       Jones, Mr. Henry  male  24.80
# 4994         4995         0       3     Harris, Mr. Robert  male  33.53
# 4995         4996         0       2     Jackson, Mr. Henry  male  34.12
# 4996         4997         0       1    Martin, Mr. Charles  male    NaN
# 4997         4998         0       3  Thompson, Mr. William  male  36.21
# 4998         4999         0       2   Robinson, Mr. Thomas  male  23.62
# 4999         5000         0       3       Davis, Mr. Frank  male  15.67
#
#       SibSp  Parch  Ticket    Fare Cabin Embarked
# 4990      0      0  964194   67.39   NaN        S
# 4991      0      1  343368   12.58   NaN        S
# 4992      0      2  186900   21.90   NaN        S
# 4993      1      0  219005   11.44   NaN        S
# 4994      1      0  464861    6.75   NaN        S
# 4995      2      0  103848   22.37   NaN        Q
# 4996      0      0  388393  114.14   NaN        S
# 4997      3      0  967618    8.43   NaN        C
# 4998      3      2  424688   26.70   NaN        S
# 4999      0      0  760435   21.89   NaN        S

# %%
print("shape of dataset:",df.shape)
# Out:
# shape of dataset: (5000, 12)

# %%
print("column of dataset:",df.columns)
# Out:
# column of dataset: Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  5000 non-null   int64
#  1   Survived     5000 non-null   int64
#  2   Pclass       5000 non-null   int64
#  3   Name         5000 non-null   str
#  4   Sex          5000 non-null   str
#  5   Age          4000 non-null   float64
#  6   SibSp        5000 non-null   int64
#  7   Parch        5000 non-null   int64
#  8   Ticket       5000 non-null   int64
#  9   Fare         4850 non-null   float64
#  10  Cabin        1250 non-null   str
#  11  Embarked     4950 non-null   str
# dtypes: float64(2), int64(6), str(4)
# memory usage: 468.9 KB
# None

# %%
print(df.describe())
# Out:
#        PassengerId     Survived       Pclass          Age        SibSp  \
# count  5000.000000  5000.000000  5000.000000  4000.000000  5000.000000
# mean   2500.500000     0.333800     2.297200    29.092408     0.539800
# std    1443.520003     0.471616     0.812283    13.130494     1.149731
# min       1.000000     0.000000     1.000000     0.420000     0.000000
# 25%    1250.750000     0.000000     2.000000    19.907500     0.000000
# 50%    2500.500000     0.000000     3.000000    28.745000     0.000000
# 75%    3750.250000     1.000000     3.000000    37.802500     1.000000
# max    5000.000000     1.000000     3.000000    76.390000     8.000000
#
#              Parch         Ticket         Fare
# count  5000.000000    5000.000000  4850.000000
# mean      0.416000  549494.294200    31.343357
# std       0.901946  259341.260501    36.022900
# min       0.000000  100198.000000     0.000000
# 25%       0.000000  327553.750000    11.150000
# 50%       0.000000  542683.500000    17.645000
# 75%       0.000000  768660.750000    29.845000
# max       6.000000  999806.000000   209.800000

# %%
print(df.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket           int64
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.isnull().sum())
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age            1000
# SibSp             0
# Parch             0
# Ticket            0
# Fare            150
# Cabin          3750
# Embarked         50
# dtype: int64

# %%
print("Missing Values Before Cleaning")
print(df.isnull().sum())
df["Age"] = df["Age"].fillna("")
df["Fare"] = df["Fare"].fillna(df["Fare"].mean())
df["Cabin"] = df["Cabin"].fillna("-")
df["Embarked"] = df["Embarked"].fillna("-")
print("\nMissing Values After Cleaning")
print(df.isnull().sum())
# Out:
# Missing Values Before Cleaning
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age            1000
# SibSp             0
# Parch             0
# Ticket            0
# Fare            150
# Cabin          3750
# Embarked         50
# dtype: int64
#
# Missing Values After Cleaning
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
Sex=df.groupby("Sex")["Survived"].sum()
plt.figure(figsize=(10,5))
plt.bar(Sex.index,Sex.values, color="skyblue")
plt.xticks(rotation=45)
plt.title("survived By Country")
plt.xlabel("Sex")
plt.ylabel("Survived")
save = input("Do you want to save graph (yes/no): ")
if save.lower() == "yes":
    plt.savefig("barchart.png",dpi=300,bbox_inches="tight")
    print("Graph Saved Successfully!")
plt.show()
# Out:
# Do you want to save graph (yes/no):  yes
# Graph Saved Successfully!

# %%
Pclass=df.groupby("Pclass")["Ticket"].sum()
plt.figure(figsize=(10,5))
plt.plot(Pclass.index,Pclass.values,marker="o",color="red")
plt.title("Ticket by Pclass")
plt.xlabel("Pclass")
plt.ylabel("Ticket")
plt.grid(True)
save = input("Do you want to save graph (yes/no): ")
if save.lower() == "yes":
    plt.savefig("Linegraph.png",dpi=300,bbox_inches="tight")
    print("Graph Saved Successfully!")
plt.show()
# Out:
# Do you want to save graph (yes/no):  yes
# Graph Saved Successfully!

# %%
Sex =df.groupby("Sex")["Ticket"].sum()
plt.figure(figsize=(8,8))
plt.pie(Sex.values,labels=Sex.index,autopct="%1.1f%%",startangle=90)
plt.title("Ticket by Sex")
save = input("Do you want to save graph (yes/no): ")
if save.lower() == "yes":
    plt.savefig("Piechart.png",dpi=300,bbox_inches="tight")
    print("Graph Saved Successfully!")
plt.show()
# Out:
# Do you want to save graph (yes/no):  yes
# Graph Saved Successfully!
