# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("dataset.csv")
print("dataset loaded successfull!")
# Out:
# dataset loaded successfull!

# %%
df.head(10)
# Out:
#    Country          Region  Year  Happiness_Rank  Happiness_Score  \
# 0  Finland  Southeast Asia  2015            93.0            5.045
# 1  Finland  Southeast Asia  2016           104.0            4.689
# 2  Finland  Southeast Asia  2017            98.0            4.769
# 3  Finland  Southeast Asia  2018           121.0              NaN
# 4  Finland  Southeast Asia  2019             NaN            4.738
# 5  Finland  Southeast Asia  2020           101.0            4.789
# 6  Finland  Southeast Asia  2021           102.0            4.694
# 7  Finland  Southeast Asia  2022           104.0            4.687
# 8  Finland  Southeast Asia  2023            96.0            4.859
# 9  Finland  Southeast Asia  2024            99.0            4.728
#
#    GDP_per_Capita  Social_Support  Healthy_Life_Expectancy  \
# 0          10.168           0.870                    53.98
# 1          10.075           0.872                    53.36
# 2          10.261           0.891                    53.44
# 3          10.049           0.854                    53.10
# 4          10.244           0.876                    54.19
# 5             NaN             NaN                    53.24
# 6          10.185           0.860                    53.08
# 7          10.186           0.849                    53.78
# 8             NaN           0.825                    53.80
# 9          10.087           0.855                    52.83
#
#    Freedom_to_Make_Life_Choices  Generosity  Perceptions_of_Corruption  \
# 0                         0.366       0.121                      0.218
# 1                         0.399       0.128                      0.218
# 2                         0.399       0.137                      0.222
# 3                         0.360       0.154                      0.254
# 4                         0.379       0.131                      0.188
# 5                         0.393       0.143                      0.254
# 6                         0.401       0.154                      0.186
# 7                         0.324       0.124                      0.232
# 8                         0.369       0.142                      0.255
# 9                         0.355       0.145                      0.224
#
#    Population_Millions  Unemployment_Rate
# 0              1363.27               7.35
# 1                18.87              23.67
# 2               255.38              19.37
# 3              1018.26               9.51
# 4               414.99               5.80
# 5               911.61              23.04
# 6               785.87              10.81
# 7               788.72              18.00
# 8               874.21                NaN
# 9              1269.59               8.26

# %%
df.tail(10)
# Out:
#        Country   Region  Year  Happiness_Rank  Happiness_Score  \
# 1540  Suriname  Oceania  2015           129.0            4.223
# 1541  Suriname  Oceania  2016           131.0              NaN
# 1542  Suriname  Oceania  2017           119.0            4.367
# 1543  Suriname  Oceania  2018           131.0            4.148
# 1544  Suriname  Oceania  2019           122.0              NaN
# 1545  Suriname  Oceania  2020           131.0            4.133
# 1546  Suriname  Oceania  2021           131.0            4.006
# 1547  Suriname  Oceania  2022           129.0            4.039
# 1548  Suriname  Oceania  2023           127.0            4.237
# 1549  Suriname  Oceania  2024           125.0            4.275
#
#       GDP_per_Capita  Social_Support  Healthy_Life_Expectancy  \
# 1540           8.925           0.703                    54.15
# 1541           8.894           0.729                    54.46
# 1542           8.893           0.684                    54.42
# 1543           8.948           0.727                      NaN
# 1544           8.865           0.699                    54.60
# 1545           8.905           0.678                    54.02
# 1546           8.824           0.754                    54.31
# 1547           8.923           0.732                    54.28
# 1548           8.763           0.683                    53.72
# 1549           8.939           0.709                    52.91
#
#       Freedom_to_Make_Life_Choices  Generosity  Perceptions_of_Corruption  \
# 1540                         0.835       0.384                      0.364
# 1541                         0.898       0.353                      0.399
# 1542                           NaN         NaN                      0.341
# 1543                         0.911       0.400                      0.344
# 1544                         0.869       0.391                      0.359
# 1545                         0.850       0.423                      0.329
# 1546                         0.882       0.382                      0.390
# 1547                         0.846       0.386                      0.367
# 1548                           NaN       0.367                      0.381
# 1549                         0.836       0.397                      0.381
#
#       Population_Millions  Unemployment_Rate
# 1540               382.87              20.31
# 1541               987.07               3.89
# 1542              1325.06              19.60
# 1543               161.87              19.13
# 1544               449.41              18.25
# 1545              1220.07              22.75
# 1546               334.51              18.97
# 1547              1369.34              20.93
# 1548                  NaN              15.93
# 1549               229.44               3.99

# %%
print("shape of dataset:",df.shape)
# Out:
# shape of dataset: (1550, 13)

# %%
print("column of dataset:",df.columns)
# Out:
# column of dataset: Index(['Country', 'Region', 'Year', 'Happiness_Rank', 'Happiness_Score',
#        'GDP_per_Capita', 'Social_Support', 'Healthy_Life_Expectancy',
#        'Freedom_to_Make_Life_Choices', 'Generosity',
#        'Perceptions_of_Corruption', 'Population_Millions',
#        'Unemployment_Rate'],
#       dtype='str')

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1550 entries, 0 to 1549
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       1550 non-null   str
#  1   Region                        1550 non-null   str
#  2   Year                          1550 non-null   int64
#  3   Happiness_Rank                1419 non-null   float64
#  4   Happiness_Score               1443 non-null   float64
#  5   GDP_per_Capita                1436 non-null   float64
#  6   Social_Support                1431 non-null   float64
#  7   Healthy_Life_Expectancy       1440 non-null   float64
#  8   Freedom_to_Make_Life_Choices  1422 non-null   float64
#  9   Generosity                    1426 non-null   float64
#  10  Perceptions_of_Corruption     1447 non-null   float64
#  11  Population_Millions           1421 non-null   float64
#  12  Unemployment_Rate             1418 non-null   float64
# dtypes: float64(10), int64(1), str(2)
# memory usage: 157.6 KB
# None

# %%
print(df.describe())
# Out:
#               Year  Happiness_Rank  Happiness_Score  GDP_per_Capita  \
# count  1550.000000     1419.000000      1443.000000     1436.000000
# mean   2019.500000       78.417195         5.338426        9.579010
# std       2.873208       44.881815         1.356676        1.082345
# min    2015.000000        1.000000         1.250000        6.565000
# 25%    2017.000000       40.000000         4.476500        8.860500
# 50%    2019.500000       78.000000         5.318000        9.723500
# 75%    2022.000000      118.000000         6.301000       10.293750
# max    2024.000000      155.000000         9.871000       12.588000
#
#        Social_Support  Healthy_Life_Expectancy  Freedom_to_Make_Life_Choices  \
# count     1431.000000              1440.000000                   1422.000000
# mean         0.721488                63.385667                      0.631216
# std          0.173033                 7.916636                      0.185912
# min          0.338000                41.230000                      0.244000
# 25%          0.579500                58.075000                      0.478250
# 50%          0.726000                63.870000                      0.645500
# 75%          0.876000                69.402500                      0.786000
# max          1.000000                80.670000                      1.000000
#
#         Generosity  Perceptions_of_Corruption  Population_Millions  \
# count  1426.000000                1447.000000          1421.000000
# mean      0.132867                   0.328133           699.713772
# std       0.154702                   0.157427           405.058092
# min      -0.136000                   0.000000             0.560000
# 25%      -0.010750                   0.196000           346.310000
# 50%       0.124500                   0.320000           711.010000
# 75%       0.272000                   0.459000          1056.430000
# max       0.426000                   0.657000          1399.090000
#
#        Unemployment_Rate
# count        1418.000000
# mean           13.505071
# std             6.673282
# min             2.000000
# 25%             7.600000
# 50%            13.270000
# 75%            19.367500
# max            24.990000

# %%
print(df.dtypes)
# Out:
# Country                             str
# Region                              str
# Year                              int64
# Happiness_Rank                  float64
# Happiness_Score                 float64
# GDP_per_Capita                  float64
# Social_Support                  float64
# Healthy_Life_Expectancy         float64
# Freedom_to_Make_Life_Choices    float64
# Generosity                      float64
# Perceptions_of_Corruption       float64
# Population_Millions             float64
# Unemployment_Rate               float64
# dtype: object

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.isnull().sum())
# Out:
# Country                           0
# Region                            0
# Year                              0
# Happiness_Rank                  131
# Happiness_Score                 107
# GDP_per_Capita                  114
# Social_Support                  119
# Healthy_Life_Expectancy         110
# Freedom_to_Make_Life_Choices    128
# Generosity                      124
# Perceptions_of_Corruption       103
# Population_Millions             129
# Unemployment_Rate               132
# dtype: int64

# %%
print("Missing Values Before Cleaning")
print(df.isnull().sum())
df["Happiness_Rank"] = df["Happiness_Rank"].fillna(df["Happiness_Rank"].mean()) 
df["Happiness_Score"] = df["Happiness_Score"].fillna(df["Happiness_Score"].mean())
df["GDP_per_Capita"] = df["GDP_per_Capita"].fillna(df["GDP_per_Capita"].mean())
df["Social_Support"] = df["Social_Support"].fillna(df["Social_Support"].mean())
df["Healthy_Life_Expectancy"] = df["Healthy_Life_Expectancy"].fillna(df["Healthy_Life_Expectancy"].mean())
df["Freedom_to_Make_Life_Choices"] = df["Freedom_to_Make_Life_Choices"].fillna(df["Freedom_to_Make_Life_Choices"].mean())
df["Generosity"] = df["Generosity"].fillna(df["Generosity"].mean())
df["Perceptions_of_Corruption"] = df["Perceptions_of_Corruption"].fillna(df["Perceptions_of_Corruption"].mean())
df["Population_Millions"] = df["Population_Millions"].fillna(df["Population_Millions"].mean())
df["Unemployment_Rate"] = df["Unemployment_Rate"].fillna(df["Unemployment_Rate"].mean())
print("\nMissing Values After Cleaning")
print(df.isnull().sum())
# Out:
# Missing Values Before Cleaning
# Country                           0
# Region                            0
# Year                              0
# Happiness_Rank                  131
# Happiness_Score                 107
# GDP_per_Capita                  114
# Social_Support                  119
# Healthy_Life_Expectancy         110
# Freedom_to_Make_Life_Choices    128
# Generosity                      124
# Perceptions_of_Corruption       103
# Population_Millions             129
# Unemployment_Rate               132
# dtype: int64
#
# Missing Values After Cleaning
# Country                         0
# Region                          0
# Year                            0
# Happiness_Rank                  0
# Happiness_Score                 0
# GDP_per_Capita                  0
# Social_Support                  0
# Healthy_Life_Expectancy         0
# Freedom_to_Make_Life_Choices    0
# Generosity                      0
# Perceptions_of_Corruption       0
# Population_Millions             0
# Unemployment_Rate               0
# dtype: int64

# %%
print(df["Country"].unique())
# Out:
# <StringArray>
# [    'Finland',     'Denmark',     'Iceland', 'Switzerland', 'Netherlands',
#       'Norway',      'Sweden',      'Israel', 'New Zealand',     'Austria',
#  ...
#      'Morocco',     'Lebanon',      'Bhutan',        'Cuba',       'Qatar',
#         'Oman',  'Azerbaijan',      'Belize',        'Fiji',    'Suriname']
# Length: 155, dtype: str

# %%
Region=df.groupby("Region")["Happiness_Rank"].sum()
plt.figure(figsize=(10,5))
plt.bar(Region.index, Region.values, color="skyblue")
plt.xticks(rotation=45)
plt.title("Happiness_Rank By Region")
plt.xlabel("Region")
plt.ylabel("Happiness_Rank")
save = input("Do you want to save graph (yes/no): ")
if save.lower() == "yes":
    plt.savefig("barchart.png",dpi=300,bbox_inches="tight")
    print("Graph Saved Successfully!")
plt.show()
# Out:
# Do you want to save graph (yes/no):  yes
# Graph Saved Successfully!

# %%
Year=df.groupby("Year")["GDP_per_Capita"].sum()
plt.figure(figsize=(10,5))
plt.plot(Year.index,Year.values,marker="o",color="red")
plt.title("GDP_per_Capita by Year")
plt.xlabel("Year")
plt.ylabel("GDP_per_Capita")
plt.grid(True)
save = input("Do you want to save graph (yes/no): ")
if save.lower() == "yes":
    plt.savefig("Linegraph.png",dpi=300,bbox_inches="tight")
    print("Graph Saved Successfully!")
plt.show()
# Out:
# Do you want to save graph (yes/no):  yes
# Graph Saved Successfully!

# %%
Year=df.groupby("Year")["Population_Millions"].sum()
plt.figure(figsize=(8,8))
plt.pie(Year.values,labels=Year.index,autopct="%1.1f%%",startangle=90)
plt.title("Population by Year")
save = input("Do you want to save graph (yes/no): ")
if save.lower() == "yes":
    plt.savefig("Piechart.png",dpi=300,bbox_inches="tight")
    print("Graph Saved Successfully!")
plt.show()
# Out:
# Do you want to save graph (yes/no):  yes
# Graph Saved Successfully!
