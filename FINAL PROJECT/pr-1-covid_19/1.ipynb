# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("covid19.csv")
print("dataset loaded successfull!")
# Out:
# dataset loaded successfull!

# %%
df.head(10)
# Out:
#    Record_ID        Date  Country  Population  New_Cases  New_Deaths  \
# 0          1  2020-01-01       UK   172644825       7296          25
# 1          2  2020-01-02    Japan    28513338      44348         758
# 2          3  2020-01-03       UK    26151125      14328         238
# 3          4  2020-01-04  Germany   189260488      35713         429
# 4          5  2020-01-05       UK    43858220      45753         432
# 5          6  2020-01-06  Germany    25896273      24898          99
# 6          7  2020-01-07  Germany   124325926      35142         127
# 7          8  2020-01-08  Germany    52617074      46174          71
# 8          9  2020-01-09   Canada    63489327       6619         389
# 9         10  2020-01-10   Brazil    96367253      13730         686
#
#    Recovered  Active_Cases  Tests_Conducted  Vaccinations  Positivity_Rate  \
# 0     1222.0          6074            94848    65737657.0           0.0769
# ...

# %%
df.tail(10)
# Out:
#       Record_ID        Date  Country  Population  New_Cases  New_Deaths  \
# 4990       4991  2020-07-09    India    23200703      28868         660
# 4991       4992  2020-07-10   Canada   153379540      42665         283
# 4992       4993  2020-07-11    Italy   130481324      45398         676
# 4993       4994  2020-07-12  Germany    81706620      13358          75
# 4994       4995  2020-07-13   Canada    56403962      22920         253
# 4995       4996  2020-07-14    Italy     9498020      38509         144
# 4996       4997  2020-07-15   Canada    10298453      48042         806
# 4997       4998  2020-07-16       UK    95580179      27374         190
# 4998       4999  2020-07-17   France   110236224      35116         386
# 4999       5000  2020-07-18    Italy     5448702      26197         586
#
#       Recovered  Active_Cases  Tests_Conducted  Vaccinations  Positivity_Rate  \
# 4990    13792.0         15076           519624    11262447.0           0.0556
# ...

# %%
print("shape of dataset:",df.shape)
# Out:
# shape of dataset: (5000, 13)

# %%
print("column of dataset:",df.columns)
# Out:
# column of dataset: Index(['Record_ID', 'Date', 'Country', 'Population', 'New_Cases', 'New_Deaths',
#        'Recovered', 'Active_Cases', 'Tests_Conducted', 'Vaccinations',
#        'Positivity_Rate', 'Hospitalized', 'ICU_Patients'],
#       dtype='str')

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Record_ID        5000 non-null   int64
#  1   Date             5000 non-null   str
#  2   Country          5000 non-null   str
#  3   Population       5000 non-null   int64
#  4   New_Cases        5000 non-null   int64
#  5   New_Deaths       5000 non-null   int64
#  6   Recovered        4750 non-null   float64
#  7   Active_Cases     5000 non-null   int64
#  8   Tests_Conducted  5000 non-null   int64
#  9   Vaccinations     4750 non-null   float64
#  10  Positivity_Rate  5000 non-null   float64
#  11  Hospitalized     4750 non-null   float64
#  12  ICU_Patients     5000 non-null   int64
# dtypes: float64(4), int64(7), str(2)
# memory usage: 507.9 KB
# None

# %%
print(df.describe())
# Out:
#          Record_ID    Population     New_Cases   New_Deaths     Recovered  \
# count  5000.000000  5.000000e+03   5000.000000  5000.000000   4750.000000
# mean   2500.500000  1.009193e+08  25032.713600   490.811600  12592.787368
# std    1443.520003  5.826441e+07  14544.437793   291.629165  11115.818692
# min       1.000000  1.024789e+06      8.000000     0.000000      1.000000
# 25%    1250.750000  4.915257e+07  12190.250000   236.000000   3420.000000
# 50%    2500.500000  1.021841e+08  25049.500000   478.000000   9358.500000
# 75%    3750.250000  1.517112e+08  37681.500000   747.000000  18954.250000
# max    5000.000000  1.997983e+08  49994.000000  1000.000000  49767.000000
#
#        Active_Cases  Tests_Conducted  Vaccinations  Positivity_Rate  \
# count    5000.00000      5000.000000  4.750000e+03      5000.000000
# mean    12455.31220    312468.849800  5.022224e+07         0.094459
# std     11013.01643    223827.581216  4.456339e+07         0.042264
# ...

# %%
print(df.isnull().sum())
# Out:
# Record_ID            0
# Date                 0
# Country              0
# Population           0
# New_Cases            0
# New_Deaths           0
# Recovered          250
# Active_Cases         0
# Tests_Conducted      0
# Vaccinations       250
# Positivity_Rate      0
# Hospitalized       250
# ICU_Patients         0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Record_ID            int64
# Date                   str
# Country                str
# Population           int64
# New_Cases            int64
# New_Deaths           int64
# Recovered          float64
# Active_Cases         int64
# Tests_Conducted      int64
# Vaccinations       float64
# Positivity_Rate    float64
# Hospitalized       float64
# ICU_Patients         int64
# dtype: object

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df["Date"] == pd.to_datetime(df["Date"]))
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 4995    True
# 4996    True
# 4997    True
# 4998    True
# 4999    True
# Name: Date, Length: 5000, dtype: bool

# %%
print("Missing Values Before Cleaning")
print(df.isnull().sum())
df["Recovered"] = df["Recovered"].fillna(df["Recovered"].mean()) 
df["Vaccinations"] = df["Vaccinations"].fillna(df["Vaccinations"].mean())
df["Hospitalized"] = df["Hospitalized"].fillna(df["Hospitalized"].mean()) 
print("\nMissing Values After Cleaning")
print(df.isnull().sum())
# Out:
# Missing Values Before Cleaning
# Record_ID            0
# Date                 0
# Country              0
# Population           0
# New_Cases            0
# New_Deaths           0
# Recovered          250
# Active_Cases         0
# Tests_Conducted      0
# Vaccinations       250
# Positivity_Rate      0
# Hospitalized       250
# ICU_Patients         0
# dtype: int64
#
# Missing Values After Cleaning
# Record_ID          0
# Date               0
# Country            0
# Population         0
# New_Cases          0
# New_Deaths         0
# Recovered          0
# Active_Cases       0
# Tests_Conducted    0
# Vaccinations       0
# Positivity_Rate    0
# Hospitalized       0
# ICU_Patients       0
# dtype: int64

# %%
print("\nCountry")
print(df["Country"].unique())
# Out:
# Country
# <StringArray>
# [       'UK',     'Japan',   'Germany',    'Canada',    'Brazil',    'France',
#  'Australia',     'India',       'USA',     'Italy']
# Length: 10, dtype: str

# %%
country =df.groupby("Country")["Population"].sum()
plt.figure(figsize=(10,5))
plt.bar(country.index, country.values, color="skyblue")
plt.xticks(rotation=45)
plt.title("Population By Country")
plt.xlabel("Country")
plt.ylabel("Population")
save = input("Do you want to save graph (yes/no): ")
if save.lower() == "yes":
    plt.savefig("barchart.png",dpi=300,bbox_inches="tight")
    print("Graph Saved Successfully!")
plt.show()
# Out:
# Do you want to save graph (yes/no):  yes
# Graph Saved Successfully!

# %%
Country =df.groupby("Country")["Vaccinations"].sum()
plt.figure(figsize=(10,5))
plt.plot(Country.index,Country.values,marker="o",color="red")
plt.title("Vaccination by Country")
plt.xlabel("Country")
plt.ylabel("Vaccinations")
plt.grid(True)
save = input("Do you want to save graph (yes/no): ")
if save.lower() == "yes":
    plt.savefig("Linegraph.png",dpi=300,bbox_inches="tight")
    print("Graph Saved Successfully!")
plt.show()
# Out:
# Do you want to save graph (yes/no):  yes
# Graph Saved Successfully!

# %%
Country =df.groupby("Country")["New_Cases"].sum()
plt.figure(figsize=(8,8))
plt.pie(Country.values,labels=Country.index,autopct="%1.1f%%",startangle=90)
plt.title("New Cases by Country")
save = input("Do you want to save graph (yes/no): ")
if save.lower() == "yes":
    plt.savefig("Piechart.png",dpi=300,bbox_inches="tight")
    print("Graph Saved Successfully!")
plt.show()
# Out:
# Do you want to save graph (yes/no):  yes
# Graph Saved Successfully!

# %%
plt.figure(figsize=(12,5))
sns.histplot(data=df, x="Country",color="purple")
plt.xticks(rotation=45)
plt.xlabel("Country")                  
plt.ylabel("New_Death")                     
plt.title("New Death by Country")
save = input("Do you want to save graph (yes/no): ")       
if save.lower() == "yes":
    plt.savefig("Histogram.png",dpi=300,bbox_inches="tight")
    print("Graph Saved Successfully!")
plt.show()
# Out:
# Do you want to save graph (yes/no):  yes
# Graph Saved Successfully!

# %% [markdown]
# The COVID-19 dataset was successfully analyzed by performing data cleaning, handling missing values, and verifying data quality to ensure accurate and reliable results. Exploratory Data Analysis (EDA) provided valuable insights into country-wise population, vaccination coverage, new COVID-19 cases, and death trends. Statistical analysis helped summarize the dataset and identify overall patterns, while visualizations such as bar charts, line graphs, pie charts, and histograms made it easier to compare the impact of COVID-19 across different countries. The analysis highlights significant differences in vaccination rates and case distribution, demonstrating the importance of data-driven approaches for monitoring disease spread, evaluating public health measures, and supporting informed decision-making during pandemics. Overall, the project showcases how Python, Pandas, NumPy, Matplotlib, and Seaborn can be effectively used to clean, analyze, and visualize real-world healthcare data for meaningful insights.
