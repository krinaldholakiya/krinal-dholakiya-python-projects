# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset.csv")

print("Dataset Loaded Successfully")
df.head()
# Out:
# Dataset Loaded Successfully
#          Date Ticker      Sector    Open    High     Low   Close  Adj_Close  \
# 0  2022-01-03   AAPL  Technology  150.33  152.27  148.57  151.41     151.25
# 1  2022-01-04   AAPL  Technology  150.89  152.65  150.83  151.94     151.35
# 2  2022-01-05   AAPL  Technology  152.52  153.69  152.35  153.64     153.56
# 3  2022-01-06   AAPL  Technology  152.16  153.03  151.78  152.70     152.67
# 4  2022-01-07   AAPL  Technology  150.69  152.58  150.58  151.55     151.30
#
#        Volume  Market_Cap_B  Daily_Return_pct
# 0   4093461.0       1988.60               NaN
# 1  11381723.0       1416.22              0.35
# 2   5957211.0       2404.27              1.12
# 3   9292463.0       1975.47             -0.61
# 4   5479530.0       1018.87             -0.75

# %%
print("Shape of Dataset")
print(df.shape)
# Out:
# Shape of Dataset
# (15640, 11)

# %%
display(df.head())

display(df.tail())
# Out:
#          Date Ticker      Sector    Open    High     Low   Close  Adj_Close  \
# 0  2022-01-03   AAPL  Technology  150.33  152.27  148.57  151.41     151.25
# 1  2022-01-04   AAPL  Technology  150.89  152.65  150.83  151.94     151.35
# 2  2022-01-05   AAPL  Technology  152.52  153.69  152.35  153.64     153.56
# 3  2022-01-06   AAPL  Technology  152.16  153.03  151.78  152.70     152.67
# 4  2022-01-07   AAPL  Technology  150.69  152.58  150.58  151.55     151.30
#
#        Volume  Market_Cap_B  Daily_Return_pct
# 0   4093461.0       1988.60               NaN
# 1  11381723.0       1416.22              0.35
# 2   5957211.0       2404.27              1.12
# 3   9292463.0       1975.47             -0.61
# 4   5479530.0       1018.87             -0.75
#              Date Ticker  Sector    Open    High     Low   Close  Adj_Close  \
# 15635  2024-12-25    XOM  Energy  198.40  203.44  198.16  201.53     201.25
# 15636  2024-12-26    XOM  Energy  195.11  197.06  194.42  195.01     194.30
# 15637  2024-12-27    XOM  Energy     NaN  195.56  192.01  195.42     194.95
# 15638  2024-12-30    XOM  Energy  193.23  196.73  192.09  194.95     194.16
# 15639  2024-12-31    XOM  Energy  190.49  191.17  189.55  190.50     189.94
#
#            Volume  Market_Cap_B  Daily_Return_pct
# 15635   8966849.0       2060.39              2.81
# 15636  11257258.0       1436.44             -3.24
# 15637   8648443.0       1278.77              0.21
# 15638   6690567.0       2685.06             -0.24
# 15639   6750105.0       2617.17             -2.28

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15640 entries, 0 to 15639
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              15640 non-null  str
#  1   Ticker            15640 non-null  str
#  2   Sector            15640 non-null  str
#  3   Open              15171 non-null  float64
#  4   High              15015 non-null  float64
#  5   Low               15015 non-null  float64
#  6   Close             15328 non-null  float64
#  7   Adj_Close         14858 non-null  float64
#  8   Volume            14546 non-null  float64
#  9   Market_Cap_B      14389 non-null  float64
#  10  Daily_Return_pct  15151 non-null  float64
# dtypes: float64(8), str(3)
# memory usage: 1.3 MB

# %%
print(df.isnull().sum())
# Out:
# Date                   0
# Ticker                 0
# Sector                 0
# Open                 469
# High                 625
# Low                  625
# Close                312
# Adj_Close            782
# Volume              1094
# Market_Cap_B        1251
# Daily_Return_pct     489
# dtype: int64

# %%
df["Open"] = df["Open"].fillna(df["Open"].mean())
df["High"] = df["High"].fillna(df["High"].mean())
df["Low"] = df["Low"].fillna(df["Low"].mean())
df["Close"] = df["Close"].fillna(df["Close"].mean())
df["Adj_Close"] = df["Adj_Close"].fillna(df["Adj_Close"].mean())
df["Volume"] = df["Volume"].fillna(df["Volume"].median())
df["Market_Cap_B"] = df["Market_Cap_B"].fillna(df["Market_Cap_B"].mean())
df["Daily_Return_pct"] = df["Daily_Return_pct"].fillna(df["Daily_Return_pct"].mean())

print("Missing Values Filled")
# Out:
# Missing Values Filled

# %%
df.drop_duplicates(inplace=True)

print("Duplicate Records Removed")
print(df.shape)
# Out:
# Duplicate Records Removed
# (15640, 11)

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj_Close  \
# count  15640.000000  15640.000000  15640.000000  15640.000000  15640.000000
# mean     193.859361    195.188827    192.389600    194.092566    193.081915
# std      145.526445    145.845265    143.553763    146.422050    143.781590
# min       12.100000     12.130000     11.950000     12.050000     11.990000
# 25%       88.297500     91.620000     91.397500     86.320000     91.787500
# 50%      157.955000    160.120000    158.130000    156.600000    160.080000
# 75%      262.817500    262.657500    258.682500    266.385000    257.750000
# max      650.820000    656.680000    649.000000    653.530000    651.390000
#
#              Volume  Market_Cap_B  Daily_Return_pct
# count  1.564000e+04  15640.000000      15640.000000
# mean   8.027268e+06   1939.767431          0.042007
# std    2.885372e+06   1635.138153          2.010912
# min    1.000000e+05     56.450000         -8.160000
# 25%    6.182106e+06    684.450000         -1.300000
# 50%    8.009341e+06   1644.610000          0.042007
# 75%    9.856440e+06   2483.985000          1.370000
# max    2.302170e+07  10143.380000          9.040000

# %%
print(df["Ticker"].unique())

print(df["Sector"].unique())
# Out:
# <StringArray>
# [ 'AAPL',   'AMD',  'AMZN',   'BAC',   'DIS', 'GOOGL',  'INTC',   'JNJ',
#    'JPM',    'KO',  'META',  'MSFT',  'NFLX',  'NVDA',   'PFE',    'PG',
#   'TSLA',     'V',   'WMT',   'XOM']
# Length: 20, dtype: str
# <StringArray>
# [            'Technology', 'Consumer Discretionary',             'Financials',
#  'Communication Services',             'Healthcare',       'Consumer Staples',
#                  'Energy']
# Length: 7, dtype: str

# %%
price = np.array(df["Close"])

print("Total =", np.sum(price))
print("Average =", np.mean(price))
print("Maximum =", np.max(price))
print("Minimum =", np.min(price))
# Out:
# Total = 3035607.730558455
# Average = 194.09256589248434
# Maximum = 653.53
# Minimum = 12.05

# %%
sector_close = df.groupby("Sector")["Close"].mean()

print(sector_close)
# Out:
# Sector
# Communication Services    293.944202
# Consumer Discretionary    312.969462
# Consumer Staples          123.449431
# Energy                    153.618032
# Financials                152.318861
# Healthcare                160.306746
# Technology                195.212513
# Name: Close, dtype: float64

# %%
sector_market = df.groupby("Sector")["Market_Cap_B"].mean()

print(sector_market)
# Out:
# Sector
# Communication Services    2850.863248
# Consumer Discretionary    3016.215014
# Consumer Staples          1281.204470
# Energy                    1559.781142
# Financials                1538.438066
# Healthcare                1642.009289
# Technology                1965.494966
# Name: Market_Cap_B, dtype: float64

# %%
sector_close.plot(kind="bar", color="skyblue", figsize=(8,5))

plt.title("Average Closing Price by Sector")
plt.xlabel("Sector")
plt.ylabel("Close Price")
plt.xticks(rotation=45)

plt.show()

# %%
df["Sector"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    figsize=(6,6)
)

plt.title("Sector Distribution")
plt.ylabel("")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Daily_Return_pct"], bins=20, color="green")

plt.title("Daily Return Distribution")
plt.xlabel("Daily Return (%)")
plt.ylabel("Frequency")

plt.show()
