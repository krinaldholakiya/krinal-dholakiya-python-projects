# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset.csv")

print("Dataset Loaded Successfully")
df.head()
# Out:
# Dataset Loaded Successfully
#          Date   City Country   PM2.5    PM10    NO2    SO2     CO     O3  \
# 0  2022-01-01  Delhi   India  155.77  194.38  61.02  21.62    NaN  14.58
# 1  2022-01-02  Delhi   India  171.72  276.43    NaN  22.33  2.383  17.21
# 2  2022-01-03  Delhi   India  142.60  211.02  65.38  17.55  1.982    NaN
# 3  2022-01-04  Delhi   India  206.71  223.59  49.81  15.09  2.454  29.10
# 4  2022-01-05  Delhi   India  168.37  266.51  48.48  19.03  2.231  23.62
#
#      AQI    AQI_Category  Temperature_C  Humidity_pct  WindSpeed_ms  \
# 0  205.0  Very Unhealthy           16.5          52.5           NaN
# 1  221.0  Very Unhealthy           17.2          47.3          5.08
# 2  196.0       Unhealthy           17.6           NaN           NaN
# 3  256.0  Very Unhealthy           16.1          48.3          2.02
# 4  218.0  Very Unhealthy           18.6          56.8          4.72
#
#    Pressure_hPa
# 0        1007.9
# 1        1012.7
# 2        1015.6
# 3        1016.9
# 4        1013.4

# %%
print("Shape of Dataset")
print(df.shape)
# Out:
# Shape of Dataset
# (21920, 15)

# %%
print("Dataset Information")
df.info()
# Out:
# Dataset Information
# <class 'pandas.DataFrame'>
# RangeIndex: 21920 entries, 0 to 21919
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           21920 non-null  str
#  1   City           21920 non-null  str
#  2   Country        21920 non-null  str
#  3   PM2.5          21044 non-null  float64
#  4   PM10           20605 non-null  float64
#  5   NO2            20824 non-null  float64
#  6   SO2            20167 non-null  float64
#  7   CO             19948 non-null  float64
#  8   O3             20824 non-null  float64
#  9   AQI            21044 non-null  float64
#  10  AQI_Category   21263 non-null  str
#  11  Temperature_C  21482 non-null  float64
#  12  Humidity_pct   21263 non-null  float64
#  13  WindSpeed_ms   20824 non-null  float64
#  14  Pressure_hPa   20605 non-null  float64
# dtypes: float64(11), str(4)
# memory usage: 2.5 MB

# %%
print("First Five Rows")
display(df.head())

print("Last Five Rows")
display(df.tail())
# Out:
# First Five Rows
#          Date   City Country   PM2.5    PM10    NO2    SO2     CO     O3  \
# 0  2022-01-01  Delhi   India  155.77  194.38  61.02  21.62    NaN  14.58
# 1  2022-01-02  Delhi   India  171.72  276.43    NaN  22.33  2.383  17.21
# 2  2022-01-03  Delhi   India  142.60  211.02  65.38  17.55  1.982    NaN
# 3  2022-01-04  Delhi   India  206.71  223.59  49.81  15.09  2.454  29.10
# 4  2022-01-05  Delhi   India  168.37  266.51  48.48  19.03  2.231  23.62
#
#      AQI    AQI_Category  Temperature_C  Humidity_pct  WindSpeed_ms  \
# 0  205.0  Very Unhealthy           16.5          52.5           NaN
# 1  221.0  Very Unhealthy           17.2          47.3          5.08
# 2  196.0       Unhealthy           17.6           NaN           NaN
# 3  256.0  Very Unhealthy           16.1          48.3          2.02
# 4  218.0  Very Unhealthy           18.6          56.8          4.72
#
#    Pressure_hPa
# 0        1007.9
# 1        1012.7
# 2        1015.6
# 3        1016.9
# 4        1013.4
# Last Five Rows
#              Date     City Country  PM2.5   PM10    NO2   SO2     CO     O3  \
# 21915  2024-12-27  Toronto  Canada  17.79  20.71  22.51   NaN    NaN  30.98
# 21916  2024-12-28  Toronto  Canada  17.76  27.33    NaN  4.71  0.486  18.57
# 21917  2024-12-29  Toronto  Canada  18.86  29.30  33.05  5.68  0.360  18.06
# 21918  2024-12-30  Toronto  Canada  21.70  30.26  21.65  4.42  0.442  22.92
# 21919  2024-12-31  Toronto  Canada  20.29  21.22  27.20  4.99  0.453  31.27
#
#         AQI AQI_Category  Temperature_C  Humidity_pct  WindSpeed_ms  \
# 21915  62.0     Moderate           -2.9          75.7          3.68
# 21916  62.0     Moderate            2.4          57.7          3.75
# 21917  65.0     Moderate            0.6          54.0          5.14
# 21918  71.0     Moderate           -2.8          46.3          0.30
# 21919  68.0     Moderate           -2.0          70.9           NaN
#
#        Pressure_hPa
# 21915        1007.9
# 21916        1022.7
# 21917        1015.2
# 21918        1021.0
# 21919        1013.1

# %%
print("Missing Values")
print(df.isnull().sum())
# Out:
# Missing Values
# Date                0
# City                0
# Country             0
# PM2.5             876
# PM10             1315
# NO2              1096
# SO2              1753
# CO               1972
# O3               1096
# AQI               876
# AQI_Category      657
# Temperature_C     438
# Humidity_pct      657
# WindSpeed_ms     1096
# Pressure_hPa     1315
# dtype: int64

# %%
df["PM2.5"] = df["PM2.5"].fillna(df["PM2.5"].mean())
df["PM10"] = df["PM10"].fillna(df["PM10"].mean())
df["NO2"] = df["NO2"].fillna(df["NO2"].mean())
df["SO2"] = df["SO2"].fillna(df["SO2"].mean())
df["CO"] = df["CO"].fillna(df["CO"].mean())
df["O3"] = df["O3"].fillna(df["O3"].mean())
df["AQI"] = df["AQI"].fillna(df["AQI"].mean())
df["Temperature_C"] = df["Temperature_C"].fillna(df["Temperature_C"].mean())
df["Humidity_pct"] = df["Humidity_pct"].fillna(df["Humidity_pct"].mean())
df["WindSpeed_ms"] = df["WindSpeed_ms"].fillna(df["WindSpeed_ms"].mean())
df["Pressure_hPa"] = df["Pressure_hPa"].fillna(df["Pressure_hPa"].mean())

print("Missing Values Filled")
# Out:
# Missing Values Filled

# %%
df.drop_duplicates(inplace=True)

print("Duplicate Records Removed")
print(df.shape)
# Out:
# Duplicate Records Removed
# (21920, 15)

# %%
df.describe()
# Out:
#               PM2.5          PM10           NO2           SO2            CO  \
# count  21920.000000  21920.000000  21920.000000  21920.000000  21920.000000
# mean      39.521469     66.049953     26.823848      7.670907      0.707743
# std       31.098267     51.405468     10.840651      4.828316      0.449662
# min        2.000000      3.000000      1.000000      0.500000      0.050000
# 25%       17.137500     29.020000     19.060000      4.130000      0.382000
# 50%       28.780000     49.690000     26.260000      6.800000      0.623000
# 75%       52.930000     87.422500     33.142500      9.860000      0.904000
# max      206.710000    388.670000     80.410000     32.820000      3.448000
#
#                  O3           AQI  Temperature_C  Humidity_pct  WindSpeed_ms  \
# count  21920.000000  21920.000000   21920.000000  21920.000000  21920.000000
# mean      33.166960     98.201625      18.422312     61.777976      3.535096
# std       13.136406     46.503203      10.173306     12.614696      1.712424
# min        2.990000      8.000000      -9.700000     10.000000      0.100000
# 25%       23.900000     61.000000      10.800000     53.400000      2.380000
# 50%       32.050000     86.000000      18.422312     61.900000      3.535096
# 75%       39.890000    144.000000      25.300000     70.600000      4.650000
# max      113.420000    256.000000      50.600000    100.000000     11.610000
#
#        Pressure_hPa
# count  21920.000000
# mean    1013.028017
# std        5.898961
# min      990.100000
# 25%     1009.200000
# 50%     1013.028017
# 75%     1016.800000
# max     1040.500000

# %%
aqi = np.array(df["AQI"])

print("Total AQI =", np.sum(aqi))
print("Average AQI =", np.mean(aqi))
print("Maximum AQI =", np.max(aqi))
print("Minimum AQI =", np.min(aqi))
# Out:
# Total AQI = 2152579.623645695
# Average AQI = 98.2016251663182
# Maximum AQI = 256.0
# Minimum AQI = 8.0

# %%
country_pm = df.groupby("Country")["PM2.5"].mean()

print(country_pm)
# Out:
# Country
# Australia      12.784048
# Brazil         22.683343
# Canada         15.055296
# China          63.811254
# Egypt          82.637635
# France         20.127824
# Germany        16.748838
# India          85.949734
# Indonesia      50.220266
# Japan          16.001774
# Mexico         40.336580
# Nigeria        58.569508
# Russia         20.638798
# South Korea    31.848780
# Thailand       38.516135
# UK             18.628341
# USA            23.055117
# Name: PM2.5, dtype: float64

# %%
country_pm = df.groupby("Country")["PM2.5"].mean()

print(country_pm)
# Out:
# Country
# Australia      12.784048
# Brazil         22.683343
# Canada         15.055296
# China          63.811254
# Egypt          82.637635
# France         20.127824
# Germany        16.748838
# India          85.949734
# Indonesia      50.220266
# Japan          16.001774
# Mexico         40.336580
# Nigeria        58.569508
# Russia         20.638798
# South Korea    31.848780
# Thailand       38.516135
# UK             18.628341
# USA            23.055117
# Name: PM2.5, dtype: float64

# %%
city_aqi = df.groupby("City")["AQI"].mean()

print(city_aqi)
# Out:
# City
# Bangkok        107.294775
# Beijing        151.809358
# Berlin          57.666309
# Cairo          157.741855
# Delhi          175.089468
# Jakarta        127.656626
# Lagos          136.732017
# London          62.555172
# Los Angeles     76.967220
# Mexico City    111.211010
# Moscow          67.639121
# Mumbai         142.660298
# New York        68.207007
# Paris           65.799344
# Sao Paulo       72.012112
# Seoul           92.853537
# Shanghai       132.482724
# Sydney          48.154801
# Tokyo           55.769212
# Toronto         53.730538
# Name: AQI, dtype: float64

# %%
city_aqi.plot(kind="bar", color="skyblue", figsize=(8,5))

plt.title("Average AQI by City")
plt.xlabel("City")
plt.ylabel("Average AQI")
plt.xticks(rotation=45)

plt.show()

# %%
df["AQI_Category"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    figsize=(6,6)
)

plt.title("AQI Category Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df["PM2.5"], bins=20, color="green")

plt.title("PM2.5 Distribution")
plt.xlabel("PM2.5")
plt.ylabel("Frequency")

plt.show()
